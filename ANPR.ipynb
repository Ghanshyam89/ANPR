# %%
# !git clone https://github.com/Ghanshyam89/ANPR.git

# %%
cd ./ANPR

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 2.7 MB/s eta 0:00:0000:01
# ...
#   Obtaining dependency information for opencv-python>=4.1.1 from https://files.pythonhosted.org/packages/b7/8a/b2f7e1a434d56bf1d7570fc5941ace0847404e1032d7f1f0b8fed896568d/opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for torchvision>=0.8.1 from https://files.pythonhosted.org/packages/84/eb/4f6483ae9094e164dc5b9b792e377f7d37823b0bedc3eef3193d416d2bb6/torchvision-0.16.0-cp310-cp310-manylinux1_x86_64.whl.metadata
# ...
#   Obtaining dependency information for tqdm>=4.64.0 from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !python predictWithOCR.py model='/ANPR/best.pt' source='/ANPR/demo.mp4'
# Out:
# Traceback (most recent call last):
#   File "/workspaces/ANPR/predictWithOCR.py", line 5, in <module>
#     import easyocr
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/easyocr/__init__.py", line 1, in <module>
#     from .easyocr import Reader
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/easyocr/easyocr.py", line 3, in <module>
#     from .recognition import get_recognizer, get_text
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/easyocr/recognition.py", line 10, in <module>
#     from .utils import CTCLabelConverter
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/easyocr/utils.py", line 7, in <module>
#     import cv2
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/usr/local/python/3.10.8/lib/python3.10/site-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
# ...
